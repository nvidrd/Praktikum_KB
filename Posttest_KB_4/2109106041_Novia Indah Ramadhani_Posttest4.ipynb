# %% [markdown]
# # Post Test 4 | Data Preprocessing
# #### Nama   : Novia Indah Ramadhani
# #### NIM    : 2109106041
# #### Kelas  : A2 2021
# ### Dataset : Brain Stroke
# #### Link   : https://www.kaggle.com/datasets/jillanisofttech/brain-stroke-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dataset_split = pd.read_csv("brain_stroke.csv")

dataset_split.head(10)
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
# 5    Male  74.0             1              1          Yes        Private
# 6  Female  69.0             0              0           No        Private
# 7  Female  78.0             0              0          Yes        Private
# 8  Female  81.0             1              0          Yes        Private
# 9  Female  61.0             0              1          Yes       Govt_job
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# ...

# %%
dataset_split.info()
dataset_split.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB
# (4981, 11)

# %% [markdown]
# ### Bagi ke Dua Var X dan Y
# #### Bagi dataset menjadi training set dan testing set dengan proporsi 70:30

# %%
x = dataset_split.iloc[:, :-1]
y = dataset_split.iloc[:, -1]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)


print("\nDIMENSI\n+--------------------------------------+")
print("Dimensi x_train", x_train.shape)
print("Dimensi x_test", x_test.shape)
print("Dimensi y_train", y_train.shape)
print("Dimensi y_test", y_test.shape)
# Out:
# DIMENSI
# +--------------------------------------+
# Dimensi x_train (3486, 10)
# Dimensi x_test (1495, 10)
# Dimensi y_train (3486,)
# Dimensi y_test (1495,)

# %% [markdown]
# ### Normalisasi
# #### Lakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler (buatlah copy dataset terlebih dahulu)

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# %%
x_norm = min_max_scaler.fit_transform(
    dataset_split[['age', 'hypertension', 'avg_glucose_level', 'bmi']]
)

data_normalisasi = pd.DataFrame(x_norm)
data_normalisasi.head()
# Out:
#           0    1         2         3
# 0  0.816895  0.0  0.801265  0.647564
# 1  0.975586  0.0  0.234512  0.530086
# 2  0.597168  0.0  0.536008  0.584527
# 3  0.963379  1.0  0.549349  0.286533
# 4  0.987793  0.0  0.605161  0.429799

# %% [markdown]
# ### Standarisasi
# #### Lakukan standarisasi pada dataset (buatlah copy dataset terlebih dahulu)

# %%
print("Nilai Standar Deviasi sebelum distandarisasi: ")
np.std(dataset_split)
# Out:
# Nilai Standar Deviasi sebelum distandarisasi:
# C:\Users\ASUS\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:3571: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# age                  22.660480
# hypertension          0.294818
# heart_disease         0.228389
# avg_glucose_level    45.070848
# bmi                   6.789782
# stroke                0.217509
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()

# %%
x_standard = standard_scaler.fit_transform(
    dataset_split[['age', 'hypertension', 'avg_glucose_level', 'bmi']]
)

print("Nilai sesudah distandarisasi: ")
np.std(x_standard)
# Out:
# Nilai sesudah distandarisasi:
# 0.9999999999999999

# %%
# Buat ngecek nilainya
np.mean(x_standard)
# Out:
# -1.305253168481212e-16

# %%
data_standarisasi = pd.DataFrame(x_standard)
data_standarisasi.head()
# Out:
#           0         1         2         3
# 0  1.040584 -0.326186  2.723411  1.193238
# 1  1.614270 -0.326186 -0.000523  0.589390
# 2  0.246250 -0.326186  1.448529  0.869222
# 3  1.570141  3.065738  1.512650 -0.662492
# 4  1.658400 -0.326186  1.780895  0.073909

# %% [markdown]
# ### Data Cleaning
# #### Lakukan Data cleaning pada data dengan nilai null (jika tidak ada nilai null pada dataset, maka buatlah menjadi ada).

# %%
# Baca Dataset yang rusak
dataset_split_rusak = pd.read_csv('brain_stroke_rusak.csv')

# Nampilin dataset dari 5-50
dataset_split_rusak[5:50]
# Out:
#     gender   age  hypertension  heart_disease ever_married      work_type  \
# 5     Male  74.0             1              1          Yes        Private
# 6   Female  69.0             0              0           No        Private
# 7   Female  78.0             0              0          Yes        Private
# 8   Female  81.0             1              0          Yes        Private
# 9   Female  61.0             0              1          Yes       Govt_job
# 10  Female  54.0             0              0          Yes        Private
# 11  Female  79.0             0              1          Yes        Private
# 12  Female   NaN             1              0          Yes  Self-employed
# 13    Male   NaN             0              1          Yes        Private
# 14    Male   NaN             1              0          Yes        Private
# 15  Female  60.0             0              0           No        Private
# 16  Female  71.0             0              0          Yes       Govt_job
# ...

# %%
print("Cek data dengan nilai NULL :")
dataset_split_rusak.isna().sum()
# Out:
# Cek data dengan nilai NULL :
# gender                0
# age                   3
# hypertension          0
# heart_disease         0
# ever_married          0
# work_type             0
# Residence_type        0
# avg_glucose_level    25
# bmi                   0
# smoking_status        0
# stroke                0
# dtype: int64

# %%
dataset_split_rusak.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# #### Ganti nilai null sesuai ketentuan. (bilangan bulat : median/modus, bilangan desimal : mean, tulisan : modus). Nilai plus jika strategy yang digunakan menggunakan 3 nilai

# %%
# Substitusi nilai NULL pada atribut avg_glucose_level dengan tipe data float dengan strategy mean
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy = "mean")
dataset_split_rusak['avg_glucose_level'] = imputer.fit_transform(dataset_split_rusak[['avg_glucose_level']])

print ("Setelah data cleaning : ")
dataset_split_rusak.isna().sum()
# Out:
# Setelah data cleaning :
# gender               0
# age                  3
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# Substitusi nilai NULL pada atribut avg_glucose_level dengan tipe data float dengan strategy mean
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy = "mean")
dataset_split_rusak['age'] = imputer.fit_transform(dataset_split_rusak[['age']])

print ("Setelah data cleaning : ")
dataset_split_rusak.isna().sum()
# Out:
# Setelah data cleaning :
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# ### Data Cleanining | Duplikat
# #### Lakukan Data cleaning pada data dengan nilai duplikat. (Jika tidak ada nilai duplikat pada dataset, maka buatlah menjadi ada)

# %%
print ("Cek data duplikat :")
dataset_split_rusak[dataset_split_rusak.duplicated()]
# Out:
# Cek data duplikat :
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 19    Female  79.0             0              0          Yes  Self-employed
# 20    Female  79.0             0              0          Yes  Self-employed
# 21    Female  79.0             0              0          Yes  Self-employed
# 22    Female  79.0             0              0          Yes  Self-employed
# 273   Female  54.0             0              0          Yes        Private
# 274   Female  54.0             0              0          Yes        Private
# 275   Female  54.0             0              0          Yes        Private
# 276   Female  54.0             0              0          Yes        Private
# 277   Female  54.0             0              0          Yes        Private
# 278   Female  54.0             0              0          Yes        Private
# 279   Female  54.0             0              0          Yes        Private
# ...

# %%
print("Jumlah data duplikat : ")
dataset_split_rusak.duplicated().sum()
# Out:
# Jumlah data duplikat :
# 21

# %%
dataset_split_rusak.drop_duplicates(inplace=True)

print ("Cek Data Duplikat : ")
dataset_split_rusak[dataset_split_rusak.duplicated()]
# Out:
# Cek Data Duplikat :
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# #### Ganti tipe data salah satu attribute angka

# %%
print ("Tipe Data Sebelum: ")
dataset_split_rusak['heart_disease'].dtypes
# Out:
# Tipe Data Sebelum:
# dtype('int64')

# %%
print ("Tipe Data Sesudah: ")
data_ganti = dataset_split_rusak[['heart_disease']].astype('float64')
data_ganti['heart_disease'].dtypes
# Out:
# Tipe Data Sesudah:
# dtype('float64')

# %% [markdown]
# ### Encoding
# #### Lakukan one hot encoding pada dataset

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# Menggunakan sparse agar mendapat data yang 2D bukan 1D

onehot_encoder = OneHotEncoder(sparse = False)

onehot = onehot_encoder.fit_transform(dataset_split_rusak[["gender"]])

dataset_split_rusak_onehot = pd.DataFrame(onehot)

dataset_split_rusak_onehot.head()

data = dataset_split_rusak.join(data_onehot)

data.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1    Male  80.0             0              1          Yes        Private
# 2  Female  49.0             0              0          Yes        Private
# 3  Female  79.0             1              0          Yes  Self-employed
# 4    Male  81.0             0              0          Yes        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke    0    1
# 0          Urban                NaN  36.6  formerly smoked       1  0.0  1.0
# 1          Rural                NaN  32.5     never smoked       1  0.0  1.0
# 2          Urban                NaN  34.4           smokes       1  1.0  0.0
# 3          Rural                NaN  24.0     never smoked       1  1.0  0.0
# 4          Urban                NaN  29.0  formerly smoked       1  0.0  1.0
